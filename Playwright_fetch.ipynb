# %% [markdown]
# <a href="https://colab.research.google.com/github/ayjulian/LawGPT/blob/main/Playwright_fetch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install bs4
! pip install playwright
! playwright install
! playwright install-deps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.9/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: playwright in /usr/local/lib/python3.9/dist-packages (1.32.1)
# Requirement already satisfied: greenlet==2.0.1 in /usr/local/lib/python3.9/dist-packages (from playwright) (2.0.1)
# Requirement already satisfied: pyee==9.0.4 in /usr/local/lib/python3.9/dist-packages (from playwright) (9.0.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from pyee==9.0.4->playwright) (4.5.0)
# Installing dependencies...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [76.4 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [995 kB]
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,034 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,283 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:15 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,331 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,114 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,499 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,182 kB]
# Fetched 12.9 MB in 6s (2,013 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libfontconfig1' instead of 'libfontconfig'
# fonts-liberation is already the newest version (1:1.07.4-11).
# libatk1.0-0 is already the newest version (2.35.1-1ubuntu2).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.36.0-2).
# libatspi2.0-0 set to manually installed.
# libcairo-gobject2 is already the newest version (1.16.0-4ubuntu1).
# libcairo-gobject2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-4ubuntu1).
# libcairo2 set to manually installed.
# libepoxy0 is already the newest version (1.5.4-1).
# libepoxy0 set to manually installed.
# libevent-2.1-7 is already the newest version (2.1.11-stable-1).
# libevent-2.1-7 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-2ubuntu3).
# libfontconfig1 set to manually installed.
# libnspr4 is already the newest version (2:4.25-1).
# libnspr4 set to manually installed.
# libopus0 is already the newest version (1.3.1-0ubuntu1).
# libopus0 set to manually installed.
# libpango-1.0-0 is already the newest version (1.44.7-2ubuntu4).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.44.7-2ubuntu4).
# libpangocairo-1.0-0 set to manually installed.
# libpangoft2-1.0-0 is already the newest version (1.44.7-2ubuntu4).
# libpangoft2-1.0-0 set to manually installed.
# libpng16-16 is already the newest version (1.6.37-2).
# libpng16-16 set to manually installed.
# libsoup2.4-1 is already the newest version (2.70.0-1).
# libsoup2.4-1 set to manually installed.
# libvpx6 is already the newest version (1.8.2-1build1).
# libvpx6 set to manually installed.
# libxcb-shm0 is already the newest version (1.14-2).
# libxcb-shm0 set to manually installed.
# libxcb1 is already the newest version (1.14-2).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1).
# libxcomposite1 set to manually installed.
# libxcursor1 is already the newest version (1:1.2.0-2).
# libxcursor1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-0ubuntu1).
# libxfixes3 is already the newest version (1:5.0.3-2).
# libxfixes3 set to manually installed.
# libxi6 is already the newest version (2:1.7.10-0ubuntu1).
# libxi6 set to manually installed.
# libxkbcommon0 is already the newest version (0.10.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-0ubuntu1).
# libxrandr2 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1).
# libxrender1 set to manually installed.
# libxshmfence1 is already the newest version (1.3-1).
# libxshmfence1 set to manually installed.
# libxt6 is already the newest version (1:1.1.5-1).
# libxt6 set to manually installed.
# libasound2 is already the newest version (1.2.2-2.1ubuntu2.5).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.34.2-0ubuntu2~20.04.1).
# libatk-bridge2.0-0 set to manually installed.
# libatomic1 is already the newest version (10.3.0-1ubuntu1~20.04).
# libatomic1 set to manually installed.
# libcups2 is already the newest version (2.3.1-9ubuntu1.2).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.16-2ubuntu2.3).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.107-8ubuntu1~20.04.2).
# libdrm2 set to manually installed.
# libegl1 is already the newest version (1.3.2-1~ubuntu0.20.04.2).
# libevdev2 is already the newest version (1.9.0+dfsg-1ubuntu0.2).
# libevdev2 set to manually installed.
# libfreetype6 is already the newest version (2.10.1-2ubuntu0.2).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (21.2.6-0ubuntu0.1~20.04.2).
# libgbm1 set to manually installed.
# libgdk-pixbuf2.0-0 is already the newest version (2.40.0+dfsg-3ubuntu0.4).
# libgdk-pixbuf2.0-0 set to manually installed.
# libgl1 is already the newest version (1.3.2-1~ubuntu0.20.04.2).
# libgles2 is already the newest version (1.3.2-1~ubuntu0.20.04.2).
# libglib2.0-0 is already the newest version (2.64.6-1~ubuntu20.04.4).
# libglib2.0-0 set to manually installed.
# libgstreamer1.0-0 is already the newest version (1.16.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# libgtk-3-0 is already the newest version (3.24.20-0ubuntu1.1).
# libgtk-3-0 set to manually installed.
# libharfbuzz0b is already the newest version (2.6.4-1ubuntu4.2).
# libharfbuzz0b set to manually installed.
# libicu66 is already the newest version (66.1-2ubuntu2.1).
# libicu66 set to manually installed.
# libjpeg-turbo8 is already the newest version (2.0.3-0ubuntu1.20.04.3).
# libjpeg-turbo8 set to manually installed.
# libnss3 is already the newest version (2:3.49.1-1ubuntu1.9).
# libnss3 set to manually installed.
# libopengl0 is already the newest version (1.3.2-1~ubuntu0.20.04.2).
# libopenjp2-7 is already the newest version (2.3.1-1ubuntu4.20.04.1).
# libopenjp2-7 set to manually installed.
# libwayland-client0 is already the newest version (1.18.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libwayland-egl1 is already the newest version (1.18.0-1ubuntu0.1).
# libwayland-egl1 set to manually installed.
# libwayland-server0 is already the newest version (1.18.0-1ubuntu0.1).
# libwayland-server0 set to manually installed.
# libwebp6 is already the newest version (0.6.1-2ubuntu0.20.04.1).
# libwebp6 set to manually installed.
# libwebpdemux2 is already the newest version (0.6.1-2ubuntu0.20.04.1).
# libx11-6 is already the newest version (2:1.6.9-2ubuntu1.2).
# libx11-6 set to manually installed.
# libx11-xcb1 is already the newest version (2:1.6.9-2ubuntu1.2).
# libx11-xcb1 set to manually installed.
# libxml2 is already the newest version (2.9.10+dfsg-5ubuntu0.20.04.6).
# libxml2 set to manually installed.
# libxslt1.1 is already the newest version (1.1.34-4ubuntu0.20.04.1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   dictionaries-common emacsen-common fonts-ubuntu hunspell-en-us libaa1
#   libaspell15 libcdparanoia0 libdca0 libdv4 libdvdnav4 libdvdread7 libfaad2
#   libfluidsynth2 libfontenc1 libgssdp-1.2-0 libgstreamer-plugins-bad1.0-0
#   libgstreamer-plugins-good1.0-0 libgupnp-1.2-0 libgupnp-igd-1.0-4
#   libhunspell-1.7-0 libinstpatch-1.0-2 libkate1 libmjpegutils-2.1-0 libmms0
#   libmodplug1 libmpcdec6 libmpeg2encpp-2.1-0 libmplex2-2.1-0 libnice10 libofa0
#   libsbc1 libsecret-common libshout3 libsoundtouch1 libspandsp2 libsrt1
#   libsrtp2-1 libtag1v5 libtag1v5-vanilla libtext-iconv-perl libusrsctp1
#   libv4l-0 libv4lconvert0 libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0
#   libwebrtc-audio-processing1 libwildmidi2 libxfont2 libxkbfile1 libzbar0
#   timgm6mb-soundfont x11-xkb-utils xfonts-encodings xfonts-utils
#   xserver-common
# Suggested packages:
#   ispell | aspell | hunspell wordlist frei0r-plugins gvfs hunspell
#   openoffice.org-hunspell | openoffice.org-core aspell libdv-bin oss-compat
#   libdvdcss2 libenchant-2-voikko libenchant-voikko libvisual-0.4-plugins
#   libwildmidi-config fluid-soundfont-gm fluidsynth timidity musescore
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma gstreamer1.0-x aspell-en
#   | aspell-dictionary | aspell6a-dictionary enchant-2 enchant gstreamer1.0-gl
#   gnome-shell | notification-daemon xfonts-base
# The following NEW packages will be installed:
#   dictionaries-common emacsen-common fonts-ipafont-gothic
#   fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-ubuntu fonts-wqy-zenhei
#   gstreamer1.0-libav gstreamer1.0-plugins-bad gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good hunspell-en-us libaa1 libaspell15 libcdparanoia0
#   libdbus-glib-1-2 libdca0 libdv4 libdvdnav4 libdvdread7 libenchant-2-2
#   libenchant1c2a libfaad2 libfluidsynth2 libfontenc1 libgssdp-1.2-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-bad1.0-0
#   libgstreamer-plugins-good1.0-0 libgupnp-1.2-0 libgupnp-igd-1.0-4
#   libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0 libinstpatch-1.0-2 libkate1
#   libmjpegutils-2.1-0 libmms0 libmodplug1 libmpcdec6 libmpeg2encpp-2.1-0
#   libmplex2-2.1-0 libnice10 libnotify4 libofa0 libsbc1 libsecret-1-0
#   libsecret-common libshout3 libsoundtouch1 libspandsp2 libsrt1 libsrtp2-1
#   libtag1v5 libtag1v5-vanilla libtext-iconv-perl libusrsctp1 libv4l-0
#   libv4lconvert0 libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0
#   libwebrtc-audio-processing1 libwildmidi2 libwoff1 libxfont2 libxkbfile1
#   libxtst6 libzbar0 timgm6mb-soundfont ttf-ubuntu-font-family ttf-unifont
#   x11-xkb-utils xfonts-cyrillic xfonts-encodings xfonts-scalable xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 79 newly installed, 0 to remove and 33 not upgraded.
# Need to get 43.2 MB of archives.
# After this operation, 111 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-wqy-zenhei all 0.9.45-7ubuntu1 [7,468 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libtext-iconv-perl amd64 1.7-7 [13.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 emacsen-common all 3.0.4 [14.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 dictionaries-common all 1.28.1 [178 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-color-emoji all 0~20200916-1~ubuntu20.04.1 [9,940 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-tlwg-loma-otf all 1:0.7.1-3 [98.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-ubuntu all 0.83-4ubuntu1 [1,458 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 gstreamer1.0-libav amd64 1.16.2-2 [123 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libvisual-0.4-0 amd64 0.4.0-17 [99.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-base amd64 1.16.3-0ubuntu1.1 [620 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libaa1 amd64 1.4p5-46 [47.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libdv4 amd64 1.0.0-12 [58.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.16.3-0ubuntu1.1 [68.7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libshout3 amd64 2.4.3-1 [50.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-0.3ubuntu2 [280 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-0.3ubuntu2 [11.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4lconvert0 amd64 1.18.0-2build1 [76.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l-0 amd64 1.18.0-2build1 [41.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-good amd64 1.16.3-0ubuntu1.1 [1,745 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 hunspell-en-us all 1:2018.04.16-1 [170 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaspell15 amd64 0.60.8-1ubuntu0.1 [328 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libdbus-glib-1-2 amd64 0.110-5fakssync1 [59.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdvdread7 amd64 6.1.0+really6.0.2-1 [49.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdvdnav4 amd64 6.0.1-1build1 [39.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libhunspell-1.7-0 amd64 1.7.0-2build2 [147 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libenchant-2-2 amd64 2.2.8-1ubuntu0.20.04.1 [45.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/universe amd64 libenchant1c2a amd64 1.6.0-11.3build1 [64.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfaad2 amd64 2.9.1-1 [154 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/universe amd64 libinstpatch-1.0-2 amd64 1.1.2-2build1 [238 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/universe amd64 timgm6mb-soundfont all 1.3-3 [5,420 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfluidsynth2 amd64 2.1.1-2 [198 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgssdp-1.2-0 amd64 1.2.3-0ubuntu0.20.04.1 [37.1 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.16.3-0ubuntu1.1 [163 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgupnp-1.2-0 amd64 1.2.4-0ubuntu1 [81.3 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgupnp-igd-1.0-4 amd64 0.2.5-5 [14.8 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libharfbuzz-icu0 amd64 2.6.4-1ubuntu4.2 [5,580 B]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libhyphen0 amd64 2.8.8-7 [27.0 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/universe amd64 libkate1 amd64 0.4.1-11build1 [39.4 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmjpegutils-2.1-0 amd64 1:2.1.0+debian-6build1 [24.1 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmms0 amd64 0.6.4-3 [27.3 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmodplug1 amd64 1:0.8.9.0-2build1 [150 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmpcdec6 amd64 2:0.1~r495-2 [32.4 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmpeg2encpp-2.1-0 amd64 1:2.1.0+debian-6build1 [69.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmplex2-2.1-0 amd64 1:2.1.0+debian-6build1 [44.4 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnice10 amd64 0.1.16-1 [136 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnotify4 amd64 0.7.9-1ubuntu3.20.04.2 [19.5 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/universe amd64 libofa0 amd64 0.9.3-21 [49.6 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-common all 0.20.4-0ubuntu1 [3,940 B]
# Get:52 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-1-0 amd64 0.20.4-0ubuntu1 [110 kB]
# Get:53 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsoundtouch1 amd64 2.1.2+ds1-1build1 [30.4 kB]
# Get:54 http://archive.ubuntu.com/ubuntu focal/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:55 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsrt1 amd64 1.4.0-1build1 [236 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsrtp2-1 amd64 2.3.0-2 [57.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/universe amd64 libusrsctp1 amd64 0.9.3.0+20190901-1 [217 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu3 [263 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:60 http://archive.ubuntu.com/ubuntu focal/main amd64 libwoff1 amd64 1.0.2-1build2 [42.0 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:64 http://archive.ubuntu.com/ubuntu focal/universe amd64 libzbar0 amd64 0.23-1.3 [119 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/universe amd64 ttf-ubuntu-font-family all 1:0.83-4ubuntu1 [10.2 kB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/main amd64 ttf-unifont all 1:12.0.01-2 [3,137 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:68 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal/universe amd64 xfonts-cyrillic all 1:1.0.4 [387 kB]
# Get:71 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-scalable all 1:1.0.3-1.1 [304 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdca0 amd64 0.0.6-1 [91.0 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.16.3-0ubuntu1 [325 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal/main amd64 libsbc1 amd64 1.4-1 [31.9 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal/universe amd64 libvo-aacenc0 amd64 0.1.3-2 [69.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2 [68.2 kB]
# Get:79 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 gstreamer1.0-plugins-bad amd64 1.16.3-0ubuntu1 [1,723 kB]
# Fetched 43.2 MB in 17s (2,562 kB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 122352 files and directories currently installed.)
# Preparing to unpack .../00-fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../01-fonts-wqy-zenhei_0.9.45-7ubuntu1_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-7ubuntu1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../02-libtext-iconv-perl_1.7-7_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7) ...
# Selecting previously unselected package emacsen-common.
# Preparing to unpack .../03-emacsen-common_3.0.4_all.deb ...
# Unpacking emacsen-common (3.0.4) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../04-dictionaries-common_1.28.1_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../05-fonts-noto-color-emoji_0~20200916-1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (0~20200916-1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../06-fonts-tlwg-loma-otf_1%3a0.7.1-3_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.1-3) ...
# Selecting previously unselected package fonts-ubuntu.
# Preparing to unpack .../07-fonts-ubuntu_0.83-4ubuntu1_all.deb ...
# Unpacking fonts-ubuntu (0.83-4ubuntu1) ...
# Selecting previously unselected package gstreamer1.0-libav:amd64.
# Preparing to unpack .../08-gstreamer1.0-libav_1.16.2-2_amd64.deb ...
# Unpacking gstreamer1.0-libav:amd64 (1.16.2-2) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../09-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../10-libvisual-0.4-0_0.4.0-17_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../11-gstreamer1.0-plugins-base_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../12-libaa1_1.4p5-46_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-46) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../13-libdv4_1.0.0-12_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-12) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../14-libgstreamer-plugins-good1.0-0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../15-libshout3_2.4.3-1_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.3-1) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../16-libtag1v5-vanilla_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../17-libtag1v5_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../18-libv4lconvert0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../19-libv4l-0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../20-gstreamer1.0-plugins-good_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../21-hunspell-en-us_1%3a2018.04.16-1_all.deb ...
# Unpacking hunspell-en-us (1:2018.04.16-1) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../22-libaspell15_0.60.8-1ubuntu0.1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-1ubuntu0.1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../23-libdbus-glib-1-2_0.110-5fakssync1_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.110-5fakssync1) ...
# Selecting previously unselected package libdvdread7:amd64.
# Preparing to unpack .../24-libdvdread7_6.1.0+really6.0.2-1_amd64.deb ...
# Unpacking libdvdread7:amd64 (6.1.0+really6.0.2-1) ...
# Selecting previously unselected package libdvdnav4:amd64.
# Preparing to unpack .../25-libdvdnav4_6.0.1-1build1_amd64.deb ...
# Unpacking libdvdnav4:amd64 (6.0.1-1build1) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../26-libhunspell-1.7-0_1.7.0-2build2_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-2build2) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../27-libenchant-2-2_2.2.8-1ubuntu0.20.04.1_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Selecting previously unselected package libenchant1c2a:amd64.
# Preparing to unpack .../28-libenchant1c2a_1.6.0-11.3build1_amd64.deb ...
# Unpacking libenchant1c2a:amd64 (1.6.0-11.3build1) ...
# Selecting previously unselected package libfaad2:amd64.
# Preparing to unpack .../29-libfaad2_2.9.1-1_amd64.deb ...
# Unpacking libfaad2:amd64 (2.9.1-1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../30-libinstpatch-1.0-2_1.1.2-2build1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.2-2build1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../31-timgm6mb-soundfont_1.3-3_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-3) ...
# Selecting previously unselected package libfluidsynth2:amd64.
# Preparing to unpack .../32-libfluidsynth2_2.1.1-2_amd64.deb ...
# Unpacking libfluidsynth2:amd64 (2.1.1-2) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../33-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libgssdp-1.2-0:amd64.
# Preparing to unpack .../34-libgssdp-1.2-0_1.2.3-0ubuntu0.20.04.1_amd64.deb ...
# Unpacking libgssdp-1.2-0:amd64 (1.2.3-0ubuntu0.20.04.1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../35-libgstreamer-gl1.0-0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libgupnp-1.2-0:amd64.
# Preparing to unpack .../36-libgupnp-1.2-0_1.2.4-0ubuntu1_amd64.deb ...
# Unpacking libgupnp-1.2-0:amd64 (1.2.4-0ubuntu1) ...
# Selecting previously unselected package libgupnp-igd-1.0-4:amd64.
# Preparing to unpack .../37-libgupnp-igd-1.0-4_0.2.5-5_amd64.deb ...
# Unpacking libgupnp-igd-1.0-4:amd64 (0.2.5-5) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../38-libharfbuzz-icu0_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../39-libhyphen0_2.8.8-7_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7) ...
# Selecting previously unselected package libkate1:amd64.
# Preparing to unpack .../40-libkate1_0.4.1-11build1_amd64.deb ...
# Unpacking libkate1:amd64 (0.4.1-11build1) ...
# Selecting previously unselected package libmjpegutils-2.1-0:amd64.
# Preparing to unpack .../41-libmjpegutils-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmms0:amd64.
# Preparing to unpack .../42-libmms0_0.6.4-3_amd64.deb ...
# Unpacking libmms0:amd64 (0.6.4-3) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../43-libmodplug1_1%3a0.8.9.0-2build1_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-2build1) ...
# Selecting previously unselected package libmpcdec6:amd64.
# Preparing to unpack .../44-libmpcdec6_2%3a0.1~r495-2_amd64.deb ...
# Unpacking libmpcdec6:amd64 (2:0.1~r495-2) ...
# Selecting previously unselected package libmpeg2encpp-2.1-0:amd64.
# Preparing to unpack .../45-libmpeg2encpp-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmplex2-2.1-0:amd64.
# Preparing to unpack .../46-libmplex2-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libnice10:amd64.
# Preparing to unpack .../47-libnice10_0.1.16-1_amd64.deb ...
# Unpacking libnice10:amd64 (0.1.16-1) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../48-libnotify4_0.7.9-1ubuntu3.20.04.2_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.9-1ubuntu3.20.04.2) ...
# Selecting previously unselected package libofa0:amd64.
# Preparing to unpack .../49-libofa0_0.9.3-21_amd64.deb ...
# Unpacking libofa0:amd64 (0.9.3-21) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../50-libsecret-common_0.20.4-0ubuntu1_all.deb ...
# Unpacking libsecret-common (0.20.4-0ubuntu1) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../51-libsecret-1-0_0.20.4-0ubuntu1_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Selecting previously unselected package libsoundtouch1:amd64.
# Preparing to unpack .../52-libsoundtouch1_2.1.2+ds1-1build1_amd64.deb ...
# Unpacking libsoundtouch1:amd64 (2.1.2+ds1-1build1) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../53-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libsrt1:amd64.
# Preparing to unpack .../54-libsrt1_1.4.0-1build1_amd64.deb ...
# Unpacking libsrt1:amd64 (1.4.0-1build1) ...
# Selecting previously unselected package libsrtp2-1:amd64.
# Preparing to unpack .../55-libsrtp2-1_2.3.0-2_amd64.deb ...
# Unpacking libsrtp2-1:amd64 (2.3.0-2) ...
# Selecting previously unselected package libusrsctp1:amd64.
# Preparing to unpack .../56-libusrsctp1_0.9.3.0+20190901-1_amd64.deb ...
# Unpacking libusrsctp1:amd64 (0.9.3.0+20190901-1) ...
# Selecting previously unselected package libwebrtc-audio-processing1:amd64.
# Preparing to unpack .../57-libwebrtc-audio-processing1_0.3.1-0ubuntu3_amd64.deb ...
# Unpacking libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu3) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../58-libwildmidi2_0.4.3-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.3-1) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../59-libwoff1_1.0.2-1build2_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build2) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../60-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../61-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../62-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libzbar0:amd64.
# Preparing to unpack .../63-libzbar0_0.23-1.3_amd64.deb ...
# Unpacking libzbar0:amd64 (0.23-1.3) ...
# Selecting previously unselected package ttf-ubuntu-font-family.
# Preparing to unpack .../64-ttf-ubuntu-font-family_1%3a0.83-4ubuntu1_all.deb ...
# Unpacking ttf-ubuntu-font-family (1:0.83-4ubuntu1) ...
# Selecting previously unselected package ttf-unifont.
# Preparing to unpack .../65-ttf-unifont_1%3a12.0.01-2_all.deb ...
# Unpacking ttf-unifont (1:12.0.01-2) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../66-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../67-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../68-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../69-xfonts-cyrillic_1%3a1.0.4_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.4) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../70-xfonts-scalable_1%3a1.0.3-1.1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.1) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../71-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../72-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package libdca0:amd64.
# Preparing to unpack .../73-libdca0_0.0.6-1_amd64.deb ...
# Unpacking libdca0:amd64 (0.0.6-1) ...
# Selecting previously unselected package libgstreamer-plugins-bad1.0-0:amd64.
# Preparing to unpack .../74-libgstreamer-plugins-bad1.0-0_1.16.3-0ubuntu1_amd64.deb ...
# Unpacking libgstreamer-plugins-bad1.0-0:amd64 (1.16.3-0ubuntu1) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../75-libsbc1_1.4-1_amd64.deb ...
# Unpacking libsbc1:amd64 (1.4-1) ...
# Selecting previously unselected package libvo-aacenc0:amd64.
# Preparing to unpack .../76-libvo-aacenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-aacenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../77-libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package gstreamer1.0-plugins-bad:amd64.
# Preparing to unpack .../78-gstreamer1.0-plugins-bad_1.16.3-0ubuntu1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-bad:amd64 (1.16.3-0ubuntu1) ...
# Setting up libtext-iconv-perl (1.7-7) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-2build1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up libsbc1:amd64 (1.4-1) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up libkate1:amd64 (0.4.1-11build1) ...
# Setting up libharfbuzz-icu0:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up libwoff1:amd64 (1.0.2-1build2) ...
# Setting up libhyphen0:amd64 (2.8.8-7) ...
# Setting up fonts-noto-color-emoji (0~20200916-1~ubuntu20.04.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17) ...
# Setting up libaspell15:amd64 (0.60.8-1ubuntu0.1) ...
# Setting up ttf-unifont (1:12.0.01-2) ...
# Setting up libdvdread7:amd64 (6.1.0+really6.0.2-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up fonts-ubuntu (0.83-4ubuntu1) ...
# Setting up libsrtp2-1:amd64 (2.3.0-2) ...
# Setting up fonts-wqy-zenhei (0.9.45-7ubuntu1) ...
# Setting up libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu3) ...
# Setting up libmpcdec6:amd64 (2:0.1~r495-2) ...
# Setting up libmms0:amd64 (0.6.4-3) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libvo-aacenc0:amd64 (0.1.3-2) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.16.3-0ubuntu1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libsoundtouch1:amd64 (2.1.2+ds1-1build1) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.1-3) ...
# Setting up emacsen-common (3.0.4) ...
# Setting up libdbus-glib-1-2:amd64 (0.110-5fakssync1) ...
# Setting up libnotify4:amd64 (0.7.9-1ubuntu3.20.04.2) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libfaad2:amd64 (2.9.1-1) ...
# Setting up libshout3:amd64 (2.4.3-1) ...
# Setting up libofa0:amd64 (0.9.3-21) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up libsrt1:amd64 (1.4.0-1build1) ...
# Setting up libdv4:amd64 (1.0.0-12) ...
# Setting up fonts-ipafont-gothic (00303-18ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libv4lconvert0:amd64 (1.18.0-2build1) ...
# Setting up libdca0:amd64 (0.0.6-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-2build2) ...
# Setting up timgm6mb-soundfont (1.3-3) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up ttf-ubuntu-font-family (1:0.83-4ubuntu1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up libusrsctp1:amd64 (0.9.3.0+20190901-1) ...
# Setting up gstreamer1.0-libav:amd64 (1.16.2-2) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.2-2build1) ...
# Setting up libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libsecret-common (0.20.4-0ubuntu1) ...
# Setting up libgssdp-1.2-0:amd64 (1.2.3-0ubuntu0.20.04.1) ...
# Setting up libdvdnav4:amd64 (6.0.1-1build1) ...
# Setting up libaa1:amd64 (1.4p5-46) ...
# Setting up libgupnp-1.2-0:amd64 (1.2.4-0ubuntu1) ...
# Setting up dictionaries-common (1.28.1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up libv4l-0:amd64 (1.18.0-2build1) ...
# Setting up libgupnp-igd-1.0-4:amd64 (0.2.5-5) ...
# Setting up libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Setting up libnice10:amd64 (0.1.16-1) ...
# Setting up libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up xfonts-cyrillic (1:1.0.4) ...
# Setting up hunspell-en-us (1:2018.04.16-1) ...
# Setting up libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up libfluidsynth2:amd64 (2.1.1-2) ...
# Setting up xfonts-scalable (1:1.0.3-1.1) ...
# Setting up libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Setting up libzbar0:amd64 (0.23-1.3) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up libenchant1c2a:amd64 (1.6.0-11.3build1) ...
# Setting up gstreamer1.0-plugins-bad:amd64 (1.16.3-0ubuntu1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for dictionaries-common (1.28.1) ...

# %%
# !pip install nest-asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (1.5.6)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
from playwright.async_api import async_playwright

async def main():
    async with async_playwright() as p:
        for browser_type in [p.chromium, p.firefox, p.webkit]:
            browser = await browser_type.launch()
            page = await browser.new_page()
            await page.goto('https://legalref.judiciary.hk/lrs/common/ju/ju_frame.jsp?DIS=152077')
            await page.screenshot(path=f'example-{browser_type.name}.png')
            await browser.close()

asyncio.run(main())
